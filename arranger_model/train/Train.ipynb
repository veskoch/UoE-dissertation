# %% [markdown]
# This notebook will help you define your seq2seq model and train it.
#
# **POINTERS**
#
# Configurations for this model are stored in 3 places. In order of hierarchy those are:
# * **Execution Parameters** Holds highest-level of settings for a particular run. Here we choose, for example, whether to train, evaluate or infer. This file loads configurations from the files below.
#     * `run_config.yml`
# * **Models** Defines the classe of the chosen model architecture(s).
#     * `model.py`
# * **Model Hyperparameters** Holds hyperparameters (i.e. optimizer, learning rate, beam width) for use on the chosen model architecture. What is interesting is that we can provide a set of different hyperparameters and test them all at once during a single run. See `config` variable inside `run_config.yml`.
#     * [`model_config.yml`]
#
#
# The model is based on Open-NMT-tf: [API Refernce](http://opennmt.net/OpenNMT-tf/package/opennmt.html) | [GitHub](https://github.com/OpenNMT/OpenNMT-tf). Most of the core is untouched. Think of this Jupyter Notebook as a thin wrapper.

# %% [markdown]
# # Run Model
#
# Execute cell bellow to run.

# %% [markdown]
# Equivalently, you can execute: `python run.py _train_config.yml` in the command line.

# %%
import run
run.main('config_train.yml')
# Out:
# INFO:tensorflow:Creating model directory run_dir/r_arb_1
# INFO:tensorflow:Using config: {'_model_dir': 'run_dir/r_arb_1', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': 300, '_save_checkpoints_secs': None, '_session_config': gpu_options {
# }
# allow_soft_placement: true
# , '_keep_checkpoint_max': 10, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x1c2e351898>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Running training and evaluation locally (non-distributed).
# INFO:tensorflow:Start train and evaluate loop. The evaluate will happen after 1800 secs (eval_spec.throttle_secs) or training is finished.
# INFO:tensorflow:Calling model_fn.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2326         with c_api_util.tf_buffer() as buf:
# -> 2327           c_api.TF_OperationGetAttrValueProto(self._c_op, name, buf)
#    2328           data = c_api.TF_GetBuffer(buf)
#
# InvalidArgumentError: Operation 'seq2seq/parallel_0/seq2seq/decoder/decoder_1/while/BasicDecoderStep/decoder/attention_wrapper/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/split' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     379     try:
# --> 380       xla_compile = op.get_attr("_XlaCompile")
#     381       xla_separate_compiled_gradients = op.get_attr(
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in get_attr(self, name)
#    2330         # Convert to ValueError for backwards compatibility.
# -> 2331         raise ValueError(str(e))
#    2332       x = attr_value_pb2.AttrValue()
#
# ValueError: Operation 'seq2seq/parallel_0/seq2seq/decoder/decoder_1/while/BasicDecoderStep/decoder/attention_wrapper/attention_wrapper/multi_rnn_cell/cell_3/lstm_cell/split' has no attr named '_XlaCompile'.
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-14db392e4364> in <module>()
#       1 import run
# ----> 2 run.main('config_train.yml')
#
# ~/GitHub/UoE-dissertation/arranger/train/r_arb_1/run.py in main(run_config)
#      83   if args.run == "train_and_eval":
#      84     runner.train_and_evaluate(checkpoint_path=args.checkpoint_path,
# ---> 85                               eval_train=args.evaluate_train)
#      86   elif args.run == "train":
#      87     runner.train()
#
# ~/GitHub/UoE-dissertation/arranger/train/r_arb_1/runner.py in train_and_evaluate(self, checkpoint_path, eval_train)
#     156     train_spec = self._build_train_spec()
#     157     eval_spec = self._build_eval_spec('eval')
# --> 158     tf.estimator.train_and_evaluate(self._estimator, train_spec, eval_spec)
#     159     self._maybe_average_checkpoints()
#     160
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/training.py in train_and_evaluate(estimator, train_spec, eval_spec)
#     437         '(with task id 0).  Given task id {}'.format(config.task_id))
#     438
# --> 439   executor.run()
#     440
#     441
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/training.py in run(self)
#     516         config.task_type != run_config_lib.TaskType.EVALUATOR):
#     517       logging.info('Running training and evaluation locally (non-distributed).')
# --> 518       self.run_local()
#     519       return
#     520
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/training.py in run_local(self)
#     648           input_fn=self._train_spec.input_fn,
#     649           max_steps=self._train_spec.max_steps,
# --> 650           hooks=train_hooks)
#     651
#     652       # Final export signal: For any eval result with global_step >= train
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in train(self, input_fn, hooks, steps, max_steps, saving_listeners)
#     361
#     362     saving_listeners = _check_listeners_type(saving_listeners)
# --> 363     loss = self._train_model(input_fn, hooks, saving_listeners)
#     364     logging.info('Loss for final step: %s.', loss)
#     365     return self
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model(self, input_fn, hooks, saving_listeners)
#     841       return self._train_model_distributed(input_fn, hooks, saving_listeners)
#     842     else:
# --> 843       return self._train_model_default(input_fn, hooks, saving_listeners)
#     844
#     845   def _train_model_default(self, input_fn, hooks, saving_listeners):
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _train_model_default(self, input_fn, hooks, saving_listeners)
#     854       worker_hooks.extend(input_hooks)
#     855       estimator_spec = self._call_model_fn(
# --> 856           features, labels, model_fn_lib.ModeKeys.TRAIN, self.config)
#     857       return self._train_with_estimator_spec(estimator_spec, worker_hooks,
#     858                                              hooks, global_step_tensor,
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/estimator/estimator.py in _call_model_fn(self, features, labels, mode, config)
#     829
#     830     logging.info('Calling model_fn.')
# --> 831     model_fn_results = self._model_fn(features=features, **kwargs)
#     832     logging.info('Done calling model_fn.')
#     833
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/opennmt/models/model.py in _model_fn(features, labels, params, mode, config)
#     104
#     105         loss = _extract_loss(losses_shards)
# --> 106         train_op = optimize(loss, params)
#     107         return tf.estimator.EstimatorSpec(
#     108             mode,
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/opennmt/utils/optim.py in optimize(loss, params)
#     141           "global_gradient_norm",
#     142       ],
# --> 143       colocate_gradients_with_ops=True)
#     144
#     145 def regularization_penalty(regularization_type, scale, weights_list=None):
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/contrib/layers/python/layers/optimizers.py in optimize_loss(loss, global_step, learning_rate, optimizer, gradient_noise_scale, gradient_multipliers, clip_gradients, learning_rate_decay_fn, update_ops, variables, name, summaries, colocate_gradients_with_ops, increment_global_step)
#     239         loss,
#     240         variables,
# --> 241         colocate_gradients_with_ops=colocate_gradients_with_ops)
#     242
#     243     # Optionally add gradient noise.
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/training/optimizer.py in compute_gradients(self, loss, var_list, gate_gradients, aggregation_method, colocate_gradients_with_ops, grad_loss)
#     524         gate_gradients=(gate_gradients == Optimizer.GATE_OP),
#     525         aggregation_method=aggregation_method,
# --> 526         colocate_gradients_with_ops=colocate_gradients_with_ops)
#     527     if gate_gradients == Optimizer.GATE_GRAPH:
#     528       grads = control_flow_ops.tuple(grads)
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in gradients(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     492   with ops.get_default_graph()._lock:  # pylint: disable=protected-access
#     493     return _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops,
# --> 494                             gate_gradients, aggregation_method, stop_gradients)
#     495
#     496
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _GradientsHelper(ys, xs, grad_ys, name, colocate_gradients_with_ops, gate_gradients, aggregation_method, stop_gradients)
#     634                 # functions.
#     635                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 636                                          lambda: grad_fn(op, *out_grads))
#     637               else:
#     638                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in _MaybeCompile(scope, op, func, grad_fn)
#     383       xla_scope = op.get_attr("_XlaScope").decode()
#     384     except ValueError:
# --> 385       return grad_fn()  # Exit early
#     386
#     387   if not xla_compile:
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gradients_impl.py in <lambda>()
#     634                 # functions.
#     635                 in_grads = _MaybeCompile(grad_scope, op, func_call,
# --> 636                                          lambda: grad_fn(op, *out_grads))
#     637               else:
#     638                 # For function call ops, we add a 'SymbolicGradient'
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/array_grad.py in _SplitGrad(op, *grads)
#     300 @ops.RegisterGradient("Split")
#     301 def _SplitGrad(op, *grads):
# --> 302   return None, array_ops.concat(list(grads), op.inputs[0])
#     303
#     304
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/array_ops.py in concat(values, axis, name)
#    1187               tensor_shape.scalar())
#    1188       return identity(values[0], name=scope)
# -> 1189   return gen_array_ops.concat_v2(values=values, axis=axis, name=name)
#    1190
#    1191
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/gen_array_ops.py in concat_v2(values, axis, name)
#     951     _attr_N = len(values)
#     952     _, _, _op = _op_def_lib._apply_op_helper(
# --> 953         "ConcatV2", values=values, axis=axis, name=name)
#     954     _result = _op.outputs[:]
#     955     _inputs_flat = _op.inputs
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/op_def_library.py in _apply_op_helper(self, op_type_name, name, **keywords)
#     785         op = g.create_op(op_type_name, inputs, output_types, name=scope,
#     786                          input_types=input_types, attrs=attr_protos,
# --> 787                          op_def=op_def)
#     788       return output_structure, op_def.is_stateful, op
#     789
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    3390           input_types=input_types,
#    3391           original_op=self._default_original_op,
# -> 3392           op_def=op_def)
#    3393
#    3394       # Note: shapes are lazily computed with the C API enabled.
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1758
#    1759     if not c_op:
# -> 1760       self._control_flow_post_processing()
#    1761
#    1762   def _control_flow_post_processing(self):
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _control_flow_post_processing(self)
#    1769       control_flow_util.CheckInputFromValidContext(self, input_tensor.op)
#    1770     if self._control_flow_context is not None:
# -> 1771       self._control_flow_context.AddOp(self)
#    1772     self._recompute_node_def()
#    1773
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in AddOp(self, op)
#    2443             op_input_ctxt._AddOpInternal(op)
#    2444             return
# -> 2445     self._AddOpInternal(op)
#    2446
#    2447   def _AddOpInternal(self, op):
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in _AddOpInternal(self, op)
#    2464       for index in range(len(op.inputs)):
#    2465         x = op.inputs[index]
# -> 2466         real_x = self.AddValue(x)
#    2467         if real_x != x:
#    2468           op._update_input(index, real_x)  # pylint: disable=protected-access
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in AddValue(self, val)
#    2396               forward_ctxt = forward_ctxt.GetWhileContext()
#    2397           if forward_ctxt == grad_ctxt.grad_state.forward_context:
# -> 2398             real_val = grad_ctxt.grad_state.GetRealValue(val)
#    2399             self._external_values[val.name] = real_val
#    2400             return real_val
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/ops/control_flow_ops.py in GetRealValue(self, value)
#    1148           # instead.
#    1149           real_value = constant_op.constant(
# -> 1150               tensor_util.constant_value(cur_value), dtype=cur_value.dtype)
#    1151           break
#    1152         else:
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/constant_op.py in constant(value, dtype, shape, name, verify_shape)
#     218       attrs={"value": tensor_value,
#     219              "dtype": dtype_value},
# --> 220       name=name).outputs[0]
#     221   return const_tensor
#     222
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in create_op(self, op_type, inputs, dtypes, input_types, name, attrs, op_def, compute_shapes, compute_device)
#    3390           input_types=input_types,
#    3391           original_op=self._default_original_op,
# -> 3392           op_def=op_def)
#    3393
#    3394       # Note: shapes are lazily computed with the C API enabled.
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in __init__(self, node_def, g, inputs, output_types, control_inputs, input_types, original_op, op_def)
#    1716     self._id_value = self._graph._next_id()  # pylint: disable=protected-access
#    1717     self._original_op = original_op
# -> 1718     self._traceback = self._graph._extract_stack()  # pylint: disable=protected-access
#    1719     self._control_flow_context = self.graph._get_control_flow_context()  # pylint: disable=protected-access
#    1720
#
# ~/anaconda3/envs/jupyter/lib/python3.6/site-packages/tensorflow/python/framework/ops.py in _extract_stack(self)
#    2982       frame_globals = f.f_globals
#    2983       func_start_lineno = co.co_firstlineno
# -> 2984       frame_info = self._extract_frame_info(f)
#    2985       ret.append((filename, lineno, name, frame_globals, func_start_lineno,
#    2986                   frame_info))
#
# KeyboardInterrupt:
